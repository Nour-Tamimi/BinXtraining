# %%
import pandas as pd

# %%
movie=pd.read_csv('C:/Users/Lenovo/Downloads/netflix_titles.csv')

# %%
movie.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
movie.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
movie.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB

# %%
movie["rating"]=movie["rating"].fillna(movie["rating"].mode()[0])
movie["duration"]=movie["duration"].fillna(movie["duration"].mode()[0])

# %%
movie["date_added"]=movie["date_added"].fillna(movie["date_added"].mode()[0])

# %%
movie["date_added"].mode()
# Out:
# 0    January 1, 2020
# Name: date_added, dtype: str

# %%
movie.drop_duplicates(inplace=True)
movie.dropna(inplace=True)

# %% [markdown]
# there is no numericl data in this dataset to apply numpy calculation on it so i have to use another one

# %%
road=pd.read_csv('C:/Users/Lenovo/Downloads/automobile_dataset.csv')

# %%
road.head()
# Out:
#             Make   Model  Year Fuel_Type Transmission  Engine_Size  Mileage  \
# 0  Mercedes-Benz     GLE  2024    Petrol    Automatic          2.3      100
# 1        Hyundai  Tucson  2008    Petrol    Automatic          2.3   387035
# 2     Volkswagen    Golf  2021    Hybrid          NaN          1.9    46054
# 3      Chevrolet   Tahoe  2005    Petrol          NaN          2.2   141302
# 4         Toyota   Camry  2022    Petrol    Automatic          1.9    32813
#
#    Horsepower  Torque  Owners  Accident_History  Service_History   Color  \
# 0       186.0   196.0       1               0.0              NaN  Silver
# 1       189.0   190.0       4               0.0              NaN    Blue
# 2       158.0   153.0       1               0.0  Partial Service    Gray
# 3       169.0   165.0       5               1.0       No Service    Blue
# 4       149.0   141.0       1               0.0     Full Service   Brown
#
#    Body_Type Drivetrain  Fuel_Efficiency Location  Selling_Price
# ...

# %%
road.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Fuel_Type             0
# Transmission        827
# Engine_Size         844
# Mileage               0
# Horsepower          800
# Torque              799
# Owners                0
# Accident_History    812
# Service_History     855
# Color               803
# Body_Type             0
# Drivetrain            0
# Fuel_Efficiency     794
# Location            782
# Selling_Price         0
# dtype: int64

# %%
road["Fuel_Efficiency"] = road["Fuel_Efficiency"].fillna(road["Fuel_Efficiency"].mean())
road["Accident_History"]=road["Accident_History"].fillna(road["Accident_History"].mean())
road["Transmission"]=road["Transmission"].fillna(road["Transmission"].mode()[0])

# %%
road.dropna(inplace=True)
road.drop_duplicates(inplace=True)

# %%
import numpy as np

# %%
road.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2095 entries, 2 to 5498
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Make              2095 non-null   str
#  1   Model             2095 non-null   str
#  2   Year              2095 non-null   int64
#  3   Fuel_Type         2095 non-null   str
#  4   Transmission      2095 non-null   str
#  5   Engine_Size       2095 non-null   float64
#  6   Mileage           2095 non-null   int64
#  7   Horsepower        2095 non-null   float64
#  8   Torque            2095 non-null   float64
#  9   Owners            2095 non-null   int64
#  10  Accident_History  2095 non-null   float64
#  11  Service_History   2095 non-null   str
#  12  Color             2095 non-null   str
#  13  Body_Type         2095 non-null   str
#  14  Drivetrain        2095 non-null   str
#  15  Fuel_Efficiency   2095 non-null   float64
#  16  Location          2095 non-null   str
# ...

# %%
milaege_array=road["Mileage"].to_numpy()
print("Milaege_array",milaege_array)
print("Mean",milaege_array.mean())
# Out:
# Milaege_array [ 46054 141302  32813 ... 287332  95961  56643]
# Mean 113398.80906921241

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(road["Horsepower"]);
plt.title("Distribution of Horsepower")
# Out:
# Text(0.5, 1.0, 'Distribution of Horsepower')

# %% [markdown]
# this is a histogram of horsepower colomn it shows the distripution of horse power like the number of cars that has a number or a range of horse power

# %%
plt.scatter(road["Year"],road["Selling_Price"]);
plt.xlabel("Year")
plt.ylabel("Selling Price")
# Out:
# Text(0, 0.5, 'Selling Price')

# %% [markdown]
# this is a scatter graph showing the relation between the selling price on the y axis and the year on the x axis

# %%
plt.bar(road["Fuel_Type"],road["Mileage"]);
plt.xlabel("Fuel_Type")
plt.ylabel("Mileage")
plt.show()

# %% [markdown]
# this is a bar graph showing the relation between the category fuel type and the mileage for each type

# %%
fig, axes =plt.subplots(2,2)
plt.tight_layout(pad=2)
axes[0,0].hist(road["Drivetrain"])
axes[0,1].bar(road["Color"],road["Engine_Size"])
# Out:
# <BarContainer object of 2095 artists>
