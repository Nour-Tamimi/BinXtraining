# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
df= pd.read_csv('C:/Users/Lenovo/Downloads/critical_minerals_supply_master.csv')

# %%
df.head()
# Out:
#    year   mineral    country  is_rare_earth    end_use  \
# 0  2015  Antimony  Australia              0  flame_ret
# 1  2016  Antimony  Australia              0  flame_ret
# 2  2017  Antimony  Australia              0  flame_ret
# 3  2018  Antimony  Australia              0  flame_ret
# 4  2019  Antimony  Australia              0  flame_ret
#
#    mine_production_tonnes  production_share_pct  reserves_tonnes  \
# 0                  5853.8                  3.97         123696.0
# 1                  6385.8                  3.95         215205.0
# 2                  6342.4                  3.75         379889.0
# 3                  7178.8                  4.09          86793.0
# 4                  6516.7                  3.89         167755.0
#
#    years_of_reserves  refined_share_pct  price_usd_per_tonne  \
# 0               21.1               3.18             11340.82
# 1               33.7               3.16             11738.55
# ...

# %%
df.shape
# Out:
# (1548, 19)

# %%
df.isna().sum()
# Out:
# year                        0
# mineral                     0
# country                     0
# is_rare_earth               0
# end_use                     0
# mine_production_tonnes      0
# production_share_pct        0
# reserves_tonnes             0
# years_of_reserves           0
# refined_share_pct           0
# price_usd_per_tonne         0
# demand_growth_pct           0
# export_control_active       0
# hhi                         0
# top_country_share_pct       0
# supply_risk_score           0
# high_supply_risk            0
# disruption                  0
# disruption_next_year      129
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    1548 non-null   int64
#  1   mineral                 1548 non-null   str
#  2   country                 1548 non-null   str
#  3   is_rare_earth           1548 non-null   int64
#  4   end_use                 1548 non-null   str
#  5   mine_production_tonnes  1548 non-null   float64
#  6   production_share_pct    1548 non-null   float64
#  7   reserves_tonnes         1548 non-null   float64
#  8   years_of_reserves       1548 non-null   float64
#  9   refined_share_pct       1548 non-null   float64
#  10  price_usd_per_tonne     1548 non-null   float64
#  11  demand_growth_pct       1548 non-null   float64
#  12  export_control_active   1548 non-null   int64
#  13  hhi                     1548 non-null   float64
# ...

# %%
df.describe()
# Out:
#               year  is_rare_earth  mine_production_tonnes  \
# count  1548.000000     1548.00000            1.548000e+03
# mean   2020.500000        0.24031            6.052152e+05
# std       3.453168        0.42741            1.987323e+06
# min    2015.000000        0.00000            4.600000e+00
# 25%    2017.750000        0.00000            4.132500e+02
# 50%    2020.500000        0.00000            7.134300e+03
# 75%    2023.250000        0.00000            9.526335e+04
# max    2026.000000        1.00000            2.457771e+07
#
#        production_share_pct  reserves_tonnes  years_of_reserves  \
# count           1548.000000     1.548000e+03        1548.000000
# mean              18.620433     1.976624e+07          34.150194
# std               23.165185     7.317379e+07          15.095650
# min                0.950000     6.900000e+01           8.000000
# 25%                5.227500     1.039400e+04          20.900000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.histplot(df['year'],discrete=True,shrink=0.8)
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %% [markdown]
# This is the distribution of years from 2015 to 2026 they all have the same count

# %%
df['is_rare_earth'].value_counts()
# Out:
# is_rare_earth
# 0    1176
# 1     372
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='is_rare_earth')
# Out:
# <Axes: xlabel='is_rare_earth', ylabel='count'>

# %% [markdown]
# this is a count of is it rare or not [rare=1,not=0]

# %%
df['mine_production_tonnes'].value_counts().sort_index().head(5)
df['mine_production_tonnes'].describe()
# Out:
# count    1.548000e+03
# mean     6.052152e+05
# std      1.987323e+06
# min      4.600000e+00
# 25%      4.132500e+02
# 50%      7.134300e+03
# 75%      9.526335e+04
# max      2.457771e+07
# Name: mine_production_tonnes, dtype: float64

# %%
bins = np.logspace(
    np.log10(df['mine_production_tonnes'].min()),
    np.log10(df['mine_production_tonnes'].max()),
    60  # number of bins
)
p=sns.histplot(df['mine_production_tonnes'],bins=bins)
p.set_xscale('log')

# %% [markdown]
# here is the distribution of the mine production tonnes i did log for x axis since it has too large values and for the bars too

# %%
df['production_share_pct'].value_counts().sort_index().head(100)
# Out:
# production_share_pct
# 0.95    2
# 0.96    1
# 0.97    1
# 0.99    3
# 1.00    1
#        ..
# 3.86    3
# 3.87    1
# 3.88    1
# 3.89    2
# 3.90    1
# Name: count, Length: 100, dtype: int64

# %%
p=sns.histplot(df['production_share_pct'],bins=100)

# %%
df['reserves_tonnes'].value_counts().sort_index()
# Out:
# reserves_tonnes
# 6.900000e+01    1
# 7.300000e+01    1
# 8.200000e+01    1
# 8.600000e+01    1
# 9.200000e+01    1
#                ..
# 6.243752e+08    1
# 6.971710e+08    1
# 7.097407e+08    1
# 9.979601e+08    1
# 1.228059e+09    1
# Name: count, Length: 1535, dtype: int64

# %%
v=sns.histplot(df['reserves_tonnes'])

# %%
df['demand_growth_pct'].value_counts().sort_index()
# Out:
# demand_growth_pct
# -4.2     1
# -2.7     1
# -2.3     1
# -2.0     1
# -1.9     1
#         ..
#  35.0    1
#  35.4    1
#  36.4    3
#  38.0    2
#  39.3    1
# Name: count, Length: 325, dtype: int64

# %%
sns.histplot(df['demand_growth_pct'])
# Out:
# <Axes: xlabel='demand_growth_pct', ylabel='Count'>

# %%
df['supply_risk_score'].value_counts().sort_index()
# Out:
# supply_risk_score
# 0.0      1
# 1.8      1
# 2.9      1
# 3.0      1
# 3.3      1
#         ..
# 92.7     1
# 96.8     1
# 98.0     1
# 98.4     1
# 100.0    1
# Name: count, Length: 647, dtype: int64

# %%
sns.histplot(df['supply_risk_score'])
# Out:
# <Axes: xlabel='supply_risk_score', ylabel='Count'>

# %%
sns.boxplot(df['supply_risk_score'])
# Out:
# <Axes: ylabel='supply_risk_score'>

# %%
psp=df['production_share_pct'].sort_index()


q1=psp.quantile(0.25)
q3=psp.quantile(0.75)
iqr=q3-q1
outliers = df[(psp < q1 - 1.5*iqr) | (psp > q3 + 1.5*iqr)]
print(outliers)
# Out:
#       year   mineral country  is_rare_earth    end_use  \
# 12    2015  Antimony   China              0  flame_ret
# 13    2016  Antimony   China              0  flame_ret
# 14    2017  Antimony   China              0  flame_ret
# 15    2018  Antimony   China              0  flame_ret
# 16    2019  Antimony   China              0  flame_ret
# ...    ...       ...     ...            ...        ...
# 1519  2022   Yttrium   China              1   phosphor
# 1520  2023   Yttrium   China              1   phosphor
# 1521  2024   Yttrium   China              1   phosphor
# 1522  2025   Yttrium   China              1   phosphor
# 1523  2026   Yttrium   China              1   phosphor
#
#       mine_production_tonnes  production_share_pct  reserves_tonnes  \
# 12                   85131.4                 57.75        2155057.0
# 13                   84696.7                 52.35        3080046.0
# 14                   89474.8                 52.93        1109999.0
# ...

# %%
sns.boxplot(df['production_share_pct'])
# Out:
# <Axes: ylabel='production_share_pct'>

# %%
sns.countplot(data=df,x='country')
# Out:
# <Axes: xlabel='country', ylabel='count'>

# %%
sns.countplot(data=df,x='end_use')
# Out:
# <Axes: xlabel='end_use', ylabel='count'>

# %%
plt.figure(figsize=(20, 7))
sns.countplot(data=df,x='mineral')
# Out:
# <Axes: xlabel='mineral', ylabel='count'>
