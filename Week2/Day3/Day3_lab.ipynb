# %%
import numpy as np

# %%
v1=np.matrix([[18,3.4,2026],
             [20,2.5,2024],
             [19,2.9,2025]])

#Student matrix [Age, GPA, Year of entering]

# %%
weight_v=np.array([2,4,6])

# %% [markdown]
# dot product by hand
# v1.weight_v =(2*18)+(4*3.4)+(6*2026)
#             =36 + 13.6 + 12,156
#             =12,205.6

# %%
dot_product=np.dot(v1[0],weight_v)
print("dot product of the first sample",dot_product)
# Out:
# dot product of the first sample [[12205.6]]

# %%
mm = v1 @ weight_v
print(mm)
# Out:
# [[12205.6 12194.  12199.6]]

# %%
m=v1*weight_v
print(m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 m=v1*weight_v
#       2 print(m)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\matrixlib\defmatrix.py:224, in matrix.__mul__(self, other)
#     221 def __mul__(self, other):
#     222     if isinstance(other, (N.ndarray, list, tuple)):
#     223         # This promotes 1-D vectors to row vectors
# --> 224         return N.dot(self, asmatrix(other))
#     225     if isscalar(other) or not hasattr(other, '__rmul__'):
#     226         return N.dot(self, other)
#
# ValueError: shapes (3,3) and (1,3) not aligned: 3 (dim 1) != 1 (dim 0)

# %%
d=np.dot(v1,weight_v)
print(d)
# Out:
# [[12205.6 12194.  12199.6]]

# %% [markdown]
# so for this i learned that @ and the dot product gets us the same result and they both only check for the inner dimension to be the same length
# but for * it has to be the exact same shape for both matricies

# %%
wrong_v=[3,6,9,12]
dot_test=np.dot(v1,wrong_v)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 wrong_v=[3,6,9,12]
# ----> 2 dot_test=np.dot(v1,wrong_v)
#
# ValueError: shapes (3,3) and (4,) not aligned: 3 (dim 1) != 4 (dim 0)

# %% [markdown]
# so the error is saying that the 2 shapes are not aligned so we cant product the vestor with 4 elements with the matrix with 3 rows and 3 columns if we want to fix this we should use a vector with the same length as the inner length of the matrix
